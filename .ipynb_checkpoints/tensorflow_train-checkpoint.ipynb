# %%
# %tensorflow_version 2.x

# %%
from tensorflow import random
import tensorflow.keras as keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.metrics import r2_score
import tensorflow as tf
import math
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# set random seed
np.random.seed(10086)
random.set_seed(10010)

# %% [markdown]
# ## Load data

# %%
raw_df = pd.read_csv("./data/PRSA_Data_Huairou_20130301-20170228.csv")

raw_dfs = []
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Aotizhongxin_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Changping_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Dingling_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Dongsi_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Guanyuan_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Huairou_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Nongzhanguan_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Shunyi_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Tiantan_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Wanliu_20130301-20170228.csv"))
raw_dfs.append(pd.read_csv("./data/PRSA_Data_Wanshouxigong_20130301-20170228.csv"))
station_info=[]
for item in raw_dfs:
    station_info.append(item["station"].values[0])
station_info
# Out:
# ['Aotizhongxin',
#  'Changping',
#  'Dingling',
#  'Dongsi',
#  'Guanyuan',
#  'Huairou',
#  'Nongzhanguan',
#  'Shunyi',
#  'Tiantan',
#  'Wanliu',
#  'Wanshouxigong']

# %%
def RHcovert(templist,dewlist):
    rh=[]
    for temp,dew in zip(templist,dewlist):
        rh.append(math.exp(17.27*dew/(237.7+dew)-17.27*temp/(237.7+temp)))
    return rh

# %%
# label to id,not used
def label_fit_transform(data_frame, col_name):

    data_frame[col_name] = preprocessing.LabelEncoder().fit_transform(data_frame[col_name])
    return data_frame
# standardization, make data form min-max to 0-1
def standardization(data_frame):
    buffer = data_frame.copy()
    min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    standard_values = min_max_scaler.fit_transform(buffer)
    for i, col_name in enumerate(buffer.columns):
        buffer[col_name] = standard_values[:, i]

    return buffer
# This step is used for lookback
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    from pandas import DataFrame, concat

    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('%s(t-%d)' % (data.columns[j], i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('%s(t)' % (data.columns[j])) for j in range(n_vars)]
        else:
            names += [('%s(t+%d)' % (data.coumns[j], i)) for j in range(n_vars)]

    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ## This part is predict $PM_{2.5}$ by current condition

# %%
# 删除时间戳
df = raw_df.drop(["No","year","month","hour", "day","wd","station"], axis=1, inplace=False)
df["RH"]=RHcovert(df["TEMP"],df["DEWP"])
df = df.drop(["TEMP","DEWP"], axis=1, inplace=False)
# df=df.drop(["PM10","SO2","NO2","CO","O3","RAIN"], axis=1)
current_data=[]
for item in raw_dfs:
    current_data.append(item.copy())
for item in current_data:
    item.drop(["No","year","month","hour", "day","wd","station"], axis=1, inplace=True)
    item["RH"]=RHcovert(item["TEMP"],item["DEWP"])
    item.drop(["TEMP","DEWP"], axis=1, inplace=True)
    item.dropna()
    item=item.reset_index()

# %%
current_data[0].head()
# Out:
#    PM2.5  PM10   SO2   NO2     CO    O3    PRES  RAIN  WSPM        RH
# 0    4.0   4.0   4.0   7.0  300.0  77.0  1023.0   0.0   4.4  0.238781
# 1    8.0   8.0   4.0   7.0  300.0  77.0  1023.2   0.0   4.7  0.258810
# 2    7.0   7.0   5.0  10.0  300.0  73.0  1023.5   0.0   5.6  0.258810
# 3    6.0   6.0  11.0  11.0  300.0  72.0  1024.5   0.0   3.1  0.238726
# 4    3.0   3.0  12.0  12.0  300.0  72.0  1025.2   0.0   2.0  0.247379

# %%
# 转化为监督序列

# %%
# 通过过去 2 小时的数据来预测未来 1 小时的数据
look_back = 2
predict_forward = 1

# %%
# standard (supervised) data frame
sdf = series_to_supervised(
    standardization(
        df), look_back, predict_forward).drop(
        [
          "PRES(t)"
         ], axis=1, inplace=False).astype('float32')

# %%
sdf
# Out:
#        index(t-2)  PM2.5(t-2)  PM10(t-2)  SO2(t-2)  NO2(t-2)   CO(t-2)  \
# 2        0.000000    0.007342   0.004040  0.006369  0.000000  0.000000
# 3        0.000143    0.002937   0.001010  0.006369  0.004367  0.010101
# 4        0.000171    0.001468   0.003030  0.101911  0.021834  0.020202
# 5        0.000200    0.001468   0.007071  0.038217  0.048035  0.030303
# 6        0.000228    0.001468   0.010101  0.105096  0.157205  0.070707
# ...           ...         ...        ...       ...       ...       ...
# 31950    0.999829    0.010279   0.008081  0.003185  0.017467  0.000000
# 31951    0.999857    0.010279   0.015152  0.003185  0.034934  0.010101
# 31952    0.999886    0.020558   0.025253  0.003185  0.074236  0.020202
# 31953    0.999914    0.027900   0.031313  0.009554  0.096070  0.040404
# 31954    0.999943    0.022026   0.030303  0.003185  0.161572  0.080808
#
#         O3(t-2)  PRES(t-2)  RAIN(t-2)  WSPM(t-2)  ...  index(t)  PM2.5(t)  \
# 2      0.204571   0.698324        0.0   0.240310  ...  0.000171  0.001468
# 3      0.191051   0.735568        0.0   0.333333  ...  0.000200  0.001468
# 4      0.184291   0.750466        0.0   0.046512  ...  0.000228  0.001468
# 5      0.159504   0.772812        0.0   0.263566  ...  0.000257  0.022026
# 6      0.100918   0.789572        0.0   0.356589  ...  0.000285  0.024963
# ...         ...        ...        ...        ...  ...       ...       ...
# 31950  0.260905   0.450652        0.0   0.155039  ...  0.999886  0.020558
# 31951  0.245131   0.463687        0.0   0.209302  ...  0.999914  0.027900
# 31952  0.213585   0.480447        0.0   0.139535  ...  0.999943  0.022026
# 31953  0.179784   0.486034        0.0   0.100775  ...  0.999972  0.013216
# 31954  0.134718   0.493482        0.0   0.116279  ...  1.000000  0.013216
#
#         PM10(t)    SO2(t)    NO2(t)     CO(t)     O3(t)  RAIN(t)   WSPM(t)  \
# 2      0.003030  0.101911  0.021834  0.020202  0.184291      0.0  0.046512
# 3      0.007071  0.038217  0.048035  0.030303  0.159504      0.0  0.263566
# 4      0.010101  0.105096  0.157205  0.070707  0.100918      0.0  0.356589
# 5      0.033333  0.156051  0.113537  0.060606  0.134718      0.0  0.379845
# 6      0.029293  0.012739  0.004367  0.020202  0.191051      0.0  0.209302
# ...         ...       ...       ...       ...       ...      ...       ...
# 31950  0.025253  0.003185  0.074236  0.020202  0.213585      0.0  0.139535
# 31951  0.031313  0.009554  0.096070  0.040404  0.179784      0.0  0.100775
# 31952  0.030303  0.003185  0.161572  0.080808  0.134718      0.0  0.116279
# 31953  0.026263  0.006369  0.131004  0.131313  0.154998      0.0  0.248062
# 31954  0.017172  0.003185  0.109170  0.030303  0.173024      0.0  0.147287
#
#           RH(t)
# 2      0.238806
# 3      0.154817
# 4      0.134706
# 5      0.123856
# 6      0.103040
# ...         ...
# 31950  0.134375
# 31951  0.134755
# 31952  0.145221
# 31953  0.144947
# 31954  0.186095
#
# [31953 rows x 32 columns]

# %%
sdf["PM2.5"]=sdf["PM2.5(t)"]
sdf=sdf.drop([
          "PM2.5(t)","PM2.5(t-1)","PM2.5(t-2)","index(t)","index(t-1)","index(t-2)"
         ],axis=1)

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31953 entries, 2 to 31954
# Data columns (total 27 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PM10(t-2)  31953 non-null  float32
#  1   SO2(t-2)   31953 non-null  float32
#  2   NO2(t-2)   31953 non-null  float32
#  3   CO(t-2)    31953 non-null  float32
#  4   O3(t-2)    31953 non-null  float32
#  5   PRES(t-2)  31953 non-null  float32
#  6   RAIN(t-2)  31953 non-null  float32
#  7   WSPM(t-2)  31953 non-null  float32
#  8   RH(t-2)    31953 non-null  float32
#  9   PM10(t-1)  31953 non-null  float32
#  10  SO2(t-1)   31953 non-null  float32
#  11  NO2(t-1)   31953 non-null  float32
#  12  CO(t-1)    31953 non-null  float32
#  13  O3(t-1)    31953 non-null  float32
#  14  PRES(t-1)  31953 non-null  float32
#  15  RAIN(t-1)  31953 non-null  float32
#  16  WSPM(t-1)  31953 non-null  float32
#  17  RH(t-1)    31953 non-null  float32
#  18  PM10(t)    31953 non-null  float32
#  19  SO2(t)     31953 non-null  float32
#  20  NO2(t)     31953 non-null  float32
#  21  CO(t)      31953 non-null  float32
#  22  O3(t)      31953 non-null  float32
#  23  RAIN(t)    31953 non-null  float32
#  24  WSPM(t)    31953 non-null  float32
#  25  RH(t)      31953 non-null  float32
#  26  PM2.5      31953 non-null  float32
# dtypes: float32(27)
# memory usage: 3.5 MB

# %%
# train, valid, test 6:2:2 划分
total = sdf.shape[0]
split_point = [total * 60 // 100, total * 80 // 100]

# %%
print("total = {}, split_point = {}".format(total, split_point))
# Out:
# total = 31953, split_point = [19171, 25562]

# %%
def transform(values):
    return values.reshape(values.shape[0], 1, values.shape[1])

# %%
train_data = sdf[:split_point[0]].values

valid_data = sdf[split_point[0]: split_point[1]].values

test_data = sdf[split_point[1]: ].values

# %%
print("train_data.shape = {}, valid_data.shape = {}, test_data.shape = {}".format(
    train_data.shape, valid_data.shape, test_data.shape))
# Out:
# train_data.shape = (19171, 27), valid_data.shape = (6391, 27), test_data.shape = (6391, 27)

# %%
train_x, train_y = transform(train_data[:, : -1]), train_data[:, -1]

valid_x, valid_y = transform(valid_data[:, : -1]), valid_data[:, -1]

test_x, test_y = transform(test_data[:, : -1]), test_data[:, -1]

# %%
print("train_x.shape = {}, train_y = {}".format(train_x.shape, train_y.shape))
print("valid_x.shape = {}, valid_y = {}".format(valid_x.shape, valid_y.shape))
print("test_x.shape = {}, test_y = {}".format(test_x.shape, test_y.shape))
# Out:
# train_x.shape = (19171, 1, 26), train_y = (19171,)
# valid_x.shape = (6391, 1, 26), valid_y = (6391,)
# test_x.shape = (6391, 1, 26), test_y = (6391,)

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(32, input_shape=(train_x.shape[1], train_x.shape[2]),activation="tanh"))
# model.add(tf.keras.layers.Dense(input_shape=(train_x.shape[1], train_x.shape[2]),units=64,activation="relu"))
model.add(tf.keras.layers.Dense(input_shape=(None,64),units=32,activation="tanh"))
model.add(tf.keras.layers.Dense(input_shape=(None,32),units=16,activation="relu"))
model.add(tf.keras.layers.Dense(input_shape=(None,16),units=1024,activation="relu"))
# model.add(tf.keras.layers.Dense(input_shape=(None,128),units=256,activation="relu"))
# model.add(tf.keras.layers.Dense(input_shape=(None,64),units=128,activation="sigmoid"))
# model.add(tf.keras.layers.Dense(units=100, activation="tanh"))
# model.add(tf.keras.layers.Dense(units=200, activation="relu"))
# model.add(tf.keras.layers.Dense(units=200, activation="sigmoid"))
model.add(keras.layers.Dense(units=1))

model.compile(loss="mae", optimizer="Adamax")

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                7552
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              17408
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 27,569
# Trainable params: 27,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_x,
                    train_y,
                    validation_data=(valid_x, valid_y),
                    epochs=10,
                    batch_size=32,
                    verbose=1,
                    shuffle=True)
# Out:
# Train on 19171 samples, validate on 6391 samples
# Epoch 1/10
# 19171/19171 [==============================] - 3s 158us/sample - loss: 0.0275 - val_loss: 0.0185
# Epoch 2/10
# 19171/19171 [==============================] - 2s 89us/sample - loss: 0.0227 - val_loss: 0.0179
# Epoch 3/10
# 19171/19171 [==============================] - 2s 86us/sample - loss: 0.0218 - val_loss: 0.0179
# Epoch 4/10
# 19171/19171 [==============================] - 2s 81us/sample - loss: 0.0211 - val_loss: 0.0171
# Epoch 5/10
# 19171/19171 [==============================] - 2s 85us/sample - loss: 0.0205 - val_loss: 0.0187
# Epoch 6/10
# 19171/19171 [==============================] - 2s 81us/sample - loss: 0.0202 - val_loss: 0.0171
# Epoch 7/10
# 19171/19171 [==============================] - 2s 81us/sample - loss: 0.0198 - val_loss: 0.0202
# Epoch 8/10
# 19171/19171 [==============================] - 2s 81us/sample - loss: 0.0198 - val_loss: 0.0219
# Epoch 9/10
# 19171/19171 [==============================] - 2s 82us/sample - loss: 0.0195 - val_loss: 0.0167
# Epoch 10/10
# 19171/19171 [==============================] - 2s 88us/sample - loss: 0.0193 - val_loss: 0.0193

# %%
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="valid loss")
plt.legend()
plt.show()

# %%
# test 集上的 loss
model.evaluate(test_x, test_y, verbose=0)
# Out:
# 0.016936834388913972

# %%
prediction = model.predict(test_x)
test_x.shape
test_y.shape
split_point[1]
# Out:
# 25562

# %%
max_value = np.max(df["PM2.5"])
min_value = np.min(df["PM2.5"])
prediction = prediction[:, 0] * (max_value - min_value) + min_value

# %%
# prediction[prediction<0]

# %%
# 因为 look_back 处理时会去掉值为 nan 的 input，所以这里要加上 look_back
expectation = df["PM2.5"][split_point[1] + look_back: ].values

# %%
print("prediction's shape = {}, expectation's shape = {}".format(prediction.shape, expectation.shape))
# Out:
# prediction's shape = (6391,), expectation's shape = (6391,)

# %%
# 计算一下 R-square
print(r2_score(expectation, prediction, multioutput="raw_values"))
# Out:
# [0.92195871]

# %%
plt.figure(figsize=(30, 17))
start=0
end=-1
plt.plot(expectation[start:end], label="expectation",color="blue")
plt.plot(prediction[start:end], label="predict", color="red")
plt.legend()
plt.show()
