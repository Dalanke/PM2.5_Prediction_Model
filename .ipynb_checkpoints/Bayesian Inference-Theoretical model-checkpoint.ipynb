# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read data
data = pd.read_csv('data/cleanup/Shunyi.csv', index_col=['date'])
data
# Out:
#                      PM2.5  PM10   SO2   NO2      CO    O3  TEMP    PRES  \
# date
# 2013-03-01 00:00:00    3.0   6.0   3.0   8.0   300.0  44.0  -0.9  1025.8
# 2013-03-01 01:00:00   12.0  12.0   3.0   7.0   300.0  47.0  -1.1  1026.1
# 2013-03-01 02:00:00   14.0  14.0   NaN   7.0   200.0  22.0  -1.7  1026.2
# 2013-03-01 03:00:00   12.0  12.0   3.0   5.0     NaN   NaN  -2.1  1027.3
# 2013-03-01 04:00:00   12.0  12.0   3.0   NaN   200.0  11.0  -2.4  1027.7
# ...                    ...   ...   ...   ...     ...   ...   ...     ...
# 2017-02-28 19:00:00   27.0  72.0   8.0  92.0   800.0  16.0  10.3  1014.2
# 2017-02-28 20:00:00   47.0  55.0  17.0  86.0  1100.0  19.0   9.8  1014.5
# 2017-02-28 21:00:00   18.0  28.0   4.0  30.0   500.0  64.0   9.1  1014.6
# 2017-02-28 22:00:00   18.0  20.0   9.0  33.0   500.0  59.0   7.1  1015.2
# 2017-02-28 23:00:00   15.0  22.0  13.0  34.0   500.0  60.0   7.4  1014.9
#
#                      DEWP  RAIN   wd  WSPM
# date
# 2013-03-01 00:00:00 -20.5   0.0   NW   9.3
# 2013-03-01 01:00:00 -21.3   0.0   NW   9.4
# 2013-03-01 02:00:00 -23.0   0.0   NW   8.6
# 2013-03-01 03:00:00 -23.3   0.0   NW   6.6
# 2013-03-01 04:00:00 -22.9   0.0   NW   4.5
# ...                   ...   ...  ...   ...
# 2017-02-28 19:00:00 -12.4   0.0    W   1.8
# 2017-02-28 20:00:00  -9.9   0.0   NW   1.5
# 2017-02-28 21:00:00 -12.7   0.0   NE   1.7
# 2017-02-28 22:00:00 -13.2   0.0  WNW   1.8
# 2017-02-28 23:00:00 -11.9   0.0    N   1.4
#
# [35064 rows x 12 columns]

# %%
# convert index to datetime object
data.index = pd.to_datetime(data.index)
data.index
# Out:
# DatetimeIndex(['2013-03-01 00:00:00', '2013-03-01 01:00:00',
#                '2013-03-01 02:00:00', '2013-03-01 03:00:00',
#                '2013-03-01 04:00:00', '2013-03-01 05:00:00',
#                '2013-03-01 06:00:00', '2013-03-01 07:00:00',
#                '2013-03-01 08:00:00', '2013-03-01 09:00:00',
#                ...
#                '2017-02-28 14:00:00', '2017-02-28 15:00:00',
#                '2017-02-28 16:00:00', '2017-02-28 17:00:00',
#                '2017-02-28 18:00:00', '2017-02-28 19:00:00',
#                '2017-02-28 20:00:00', '2017-02-28 21:00:00',
#                '2017-02-28 22:00:00', '2017-02-28 23:00:00'],
#               dtype='datetime64[ns]', name='date', length=35064, freq=None)

# %%
# explore relationship between wind speed and PM2.5 
df_daily1 = data[data.index.strftime('%Y-%m-%d') == '2013-03-01']
print(df_daily1['wd'])
df_daily1['PM2.5'].plot()
# Out:
# date
# 2013-03-01 00:00:00     NW
# 2013-03-01 01:00:00     NW
# 2013-03-01 02:00:00     NW
# 2013-03-01 03:00:00     NW
# 2013-03-01 04:00:00     NW
# 2013-03-01 05:00:00    NNW
# 2013-03-01 06:00:00    NNE
# 2013-03-01 07:00:00     NE
# 2013-03-01 08:00:00    NNW
# 2013-03-01 09:00:00    SSW
# 2013-03-01 10:00:00    NNW
# 2013-03-01 11:00:00    NNW
# 2013-03-01 12:00:00     NE
# 2013-03-01 13:00:00     NE
# 2013-03-01 14:00:00    ENE
# 2013-03-01 15:00:00     NE
# 2013-03-01 16:00:00    NNE
# 2013-03-01 17:00:00    NNW
# 2013-03-01 18:00:00     NW
# 2013-03-01 19:00:00      N
# 2013-03-01 20:00:00     NE
# 2013-03-01 21:00:00    ENE
# 2013-03-01 22:00:00    ENE
# 2013-03-01 23:00:00     NE
# Name: wd, dtype: object

# %%
# exam the Autocorrelation of PM2.5

from statsmodels.graphics import tsaplots
fig = tsaplots.plot_acf(df_daily1['PM2.5'])
plt.show()

# %% [markdown]
# ## Preprocessing---how to calculate change rate of PM2.5 (μg.m3-1/hour)

# %%
# One our prediction seems like a reasonable choice

'''
Modify the data accoring to EDA, drop 'wd', drop na, turn temperature and dew point into RH(relative humidity)
calculate one houre PM2.5 change rate
'''
import math

# drop 'wd' first
data.drop(columns=['wd'], inplace=True)
# convert temperature/dew point into RH
data['RH'] = data.apply(lambda x: math.exp(17.27*x.DEWP/(237.7+x.DEWP)-17.27*x.TEMP/(237.7+x.TEMP)), axis=1)
data
# Out:
#                      PM2.5  PM10   SO2   NO2      CO    O3  TEMP    PRES  \
# date
# 2013-03-01 00:00:00    3.0   6.0   3.0   8.0   300.0  44.0  -0.9  1025.8
# 2013-03-01 01:00:00   12.0  12.0   3.0   7.0   300.0  47.0  -1.1  1026.1
# 2013-03-01 02:00:00   14.0  14.0   NaN   7.0   200.0  22.0  -1.7  1026.2
# 2013-03-01 03:00:00   12.0  12.0   3.0   5.0     NaN   NaN  -2.1  1027.3
# 2013-03-01 04:00:00   12.0  12.0   3.0   NaN   200.0  11.0  -2.4  1027.7
# ...                    ...   ...   ...   ...     ...   ...   ...     ...
# 2017-02-28 19:00:00   27.0  72.0   8.0  92.0   800.0  16.0  10.3  1014.2
# 2017-02-28 20:00:00   47.0  55.0  17.0  86.0  1100.0  19.0   9.8  1014.5
# 2017-02-28 21:00:00   18.0  28.0   4.0  30.0   500.0  64.0   9.1  1014.6
# 2017-02-28 22:00:00   18.0  20.0   9.0  33.0   500.0  59.0   7.1  1015.2
# 2017-02-28 23:00:00   15.0  22.0  13.0  34.0   500.0  60.0   7.4  1014.9
#
#                      DEWP  RAIN  WSPM        RH
# date
# 2013-03-01 00:00:00 -20.5   0.0   9.3  0.209222
# 2013-03-01 01:00:00 -21.3   0.0   9.4  0.197983
# 2013-03-01 02:00:00 -23.0   0.0   8.6  0.178054
# 2013-03-01 03:00:00 -23.3   0.0   6.6  0.178550
# 2013-03-01 04:00:00 -22.9   0.0   4.5  0.189187
# ...                   ...   ...   ...       ...
# 2017-02-28 19:00:00 -12.4   0.0   1.8  0.188669
# 2017-02-28 20:00:00  -9.9   0.0   1.5  0.238267
# 2017-02-28 21:00:00 -12.7   0.0   1.7  0.199573
# 2017-02-28 22:00:00 -13.2   0.0   1.8  0.219519
# 2017-02-28 23:00:00 -11.9   0.0   1.4  0.238934
#
# [35064 rows x 12 columns]

# %%
# now we can drop the TEMP and DEWP
data_new = data.drop(columns=['TEMP', 'DEWP'])
data_new
# Out:
#                      PM2.5  PM10   SO2   NO2      CO    O3    PRES  RAIN  \
# date
# 2013-03-01 00:00:00    3.0   6.0   3.0   8.0   300.0  44.0  1025.8   0.0
# 2013-03-01 01:00:00   12.0  12.0   3.0   7.0   300.0  47.0  1026.1   0.0
# 2013-03-01 02:00:00   14.0  14.0   NaN   7.0   200.0  22.0  1026.2   0.0
# 2013-03-01 03:00:00   12.0  12.0   3.0   5.0     NaN   NaN  1027.3   0.0
# 2013-03-01 04:00:00   12.0  12.0   3.0   NaN   200.0  11.0  1027.7   0.0
# ...                    ...   ...   ...   ...     ...   ...     ...   ...
# 2017-02-28 19:00:00   27.0  72.0   8.0  92.0   800.0  16.0  1014.2   0.0
# 2017-02-28 20:00:00   47.0  55.0  17.0  86.0  1100.0  19.0  1014.5   0.0
# 2017-02-28 21:00:00   18.0  28.0   4.0  30.0   500.0  64.0  1014.6   0.0
# 2017-02-28 22:00:00   18.0  20.0   9.0  33.0   500.0  59.0  1015.2   0.0
# 2017-02-28 23:00:00   15.0  22.0  13.0  34.0   500.0  60.0  1014.9   0.0
#
#                      WSPM        RH
# date
# 2013-03-01 00:00:00   9.3  0.209222
# 2013-03-01 01:00:00   9.4  0.197983
# 2013-03-01 02:00:00   8.6  0.178054
# 2013-03-01 03:00:00   6.6  0.178550
# 2013-03-01 04:00:00   4.5  0.189187
# ...                   ...       ...
# 2017-02-28 19:00:00   1.8  0.188669
# 2017-02-28 20:00:00   1.5  0.238267
# 2017-02-28 21:00:00   1.7  0.199573
# 2017-02-28 22:00:00   1.8  0.219519
# 2017-02-28 23:00:00   1.4  0.238934
#
# [35064 rows x 10 columns]

# %%
# here we shift 1 to obtain 1 hour PM2.5 change rate
data_new['PM1hour'] = data_new['PM2.5'].shift(periods=-1)
data_new
# Out:
#                      PM2.5  PM10   SO2   NO2      CO    O3    PRES  RAIN  \
# date
# 2013-03-01 00:00:00    3.0   6.0   3.0   8.0   300.0  44.0  1025.8   0.0
# 2013-03-01 01:00:00   12.0  12.0   3.0   7.0   300.0  47.0  1026.1   0.0
# 2013-03-01 02:00:00   14.0  14.0   NaN   7.0   200.0  22.0  1026.2   0.0
# 2013-03-01 03:00:00   12.0  12.0   3.0   5.0     NaN   NaN  1027.3   0.0
# 2013-03-01 04:00:00   12.0  12.0   3.0   NaN   200.0  11.0  1027.7   0.0
# ...                    ...   ...   ...   ...     ...   ...     ...   ...
# 2017-02-28 19:00:00   27.0  72.0   8.0  92.0   800.0  16.0  1014.2   0.0
# 2017-02-28 20:00:00   47.0  55.0  17.0  86.0  1100.0  19.0  1014.5   0.0
# 2017-02-28 21:00:00   18.0  28.0   4.0  30.0   500.0  64.0  1014.6   0.0
# 2017-02-28 22:00:00   18.0  20.0   9.0  33.0   500.0  59.0  1015.2   0.0
# 2017-02-28 23:00:00   15.0  22.0  13.0  34.0   500.0  60.0  1014.9   0.0
#
#                      WSPM        RH  PM1hour
# date
# 2013-03-01 00:00:00   9.3  0.209222     12.0
# 2013-03-01 01:00:00   9.4  0.197983     14.0
# 2013-03-01 02:00:00   8.6  0.178054     12.0
# 2013-03-01 03:00:00   6.6  0.178550     12.0
# 2013-03-01 04:00:00   4.5  0.189187     11.0
# ...                   ...       ...      ...
# 2017-02-28 19:00:00   1.8  0.188669     47.0
# 2017-02-28 20:00:00   1.5  0.238267     18.0
# 2017-02-28 21:00:00   1.7  0.199573     18.0
# 2017-02-28 22:00:00   1.8  0.219519     15.0
# 2017-02-28 23:00:00   1.4  0.238934      NaN
#
# [35064 rows x 11 columns]

# %%
# 1 hour PM2.5 change rate
data_new['PM2.5Change'] = data_new.apply(lambda x: x.PM1hour - x['PM2.5'] if ((not pd.isna(x.PM1hour)) and (not pd.isna(x['PM2.5']))) else np.nan, axis=1)
data_new
# Out:
#                      PM2.5  PM10   SO2   NO2      CO    O3    PRES  RAIN  \
# date
# 2013-03-01 00:00:00    3.0   6.0   3.0   8.0   300.0  44.0  1025.8   0.0
# 2013-03-01 01:00:00   12.0  12.0   3.0   7.0   300.0  47.0  1026.1   0.0
# 2013-03-01 02:00:00   14.0  14.0   NaN   7.0   200.0  22.0  1026.2   0.0
# 2013-03-01 03:00:00   12.0  12.0   3.0   5.0     NaN   NaN  1027.3   0.0
# 2013-03-01 04:00:00   12.0  12.0   3.0   NaN   200.0  11.0  1027.7   0.0
# ...                    ...   ...   ...   ...     ...   ...     ...   ...
# 2017-02-28 19:00:00   27.0  72.0   8.0  92.0   800.0  16.0  1014.2   0.0
# 2017-02-28 20:00:00   47.0  55.0  17.0  86.0  1100.0  19.0  1014.5   0.0
# 2017-02-28 21:00:00   18.0  28.0   4.0  30.0   500.0  64.0  1014.6   0.0
# 2017-02-28 22:00:00   18.0  20.0   9.0  33.0   500.0  59.0  1015.2   0.0
# 2017-02-28 23:00:00   15.0  22.0  13.0  34.0   500.0  60.0  1014.9   0.0
#
#                      WSPM        RH  PM1hour  PM2.5Change
# date
# 2013-03-01 00:00:00   9.3  0.209222     12.0          9.0
# 2013-03-01 01:00:00   9.4  0.197983     14.0          2.0
# 2013-03-01 02:00:00   8.6  0.178054     12.0         -2.0
# 2013-03-01 03:00:00   6.6  0.178550     12.0          0.0
# 2013-03-01 04:00:00   4.5  0.189187     11.0         -1.0
# ...                   ...       ...      ...          ...
# 2017-02-28 19:00:00   1.8  0.188669     47.0         20.0
# 2017-02-28 20:00:00   1.5  0.238267     18.0        -29.0
# 2017-02-28 21:00:00   1.7  0.199573     18.0          0.0
# 2017-02-28 22:00:00   1.8  0.219519     15.0         -3.0
# 2017-02-28 23:00:00   1.4  0.238934      NaN          NaN
#
# [35064 rows x 12 columns]

# %%
# how many rows that we don't have data?

data_new[data_new['PM2.5Change'].isna()]
# Out:
#                      PM2.5   PM10   SO2   NO2      CO    O3    PRES  RAIN  \
# date
# 2013-03-09 11:00:00   76.0  764.0  59.0  66.0  1500.0  90.0  1003.6   0.0
# 2013-03-09 12:00:00    NaN    NaN   NaN   NaN     NaN  90.0  1006.6   0.0
# 2013-03-09 13:00:00    NaN    NaN   NaN   NaN     NaN  90.0  1009.0   0.0
# 2013-03-09 14:00:00    NaN    NaN   NaN   NaN     NaN  90.0  1010.4   0.0
# 2013-03-09 15:00:00    NaN    NaN   NaN   NaN     NaN  90.0  1011.7   0.0
# ...                    ...    ...   ...   ...     ...   ...     ...   ...
# 2017-02-21 13:00:00    NaN    NaN   NaN   NaN     NaN   NaN  1027.8   0.0
# 2017-02-23 15:00:00    4.0    6.0   3.0  14.0   200.0  87.0  1022.8   0.0
# 2017-02-23 16:00:00    NaN    NaN   2.0  14.0   300.0  84.0  1022.5   0.0
# 2017-02-23 17:00:00    NaN    NaN   2.0  17.0   300.0   NaN  1022.2   0.0
# 2017-02-28 23:00:00   15.0   22.0  13.0  34.0   500.0  60.0  1014.9   0.0
#
#                      WSPM        RH  PM1hour  PM2.5Change
# date
# 2013-03-09 11:00:00   9.7  0.159041      NaN          NaN
# 2013-03-09 12:00:00   9.9  0.129068      NaN          NaN
# 2013-03-09 13:00:00   7.6  0.139415      NaN          NaN
# 2013-03-09 14:00:00   6.2  0.129010      NaN          NaN
# 2013-03-09 15:00:00   5.9  0.128784      NaN          NaN
# ...                   ...       ...      ...          ...
# 2017-02-21 13:00:00   3.6  0.530891     59.0          NaN
# 2017-02-23 15:00:00   3.5  0.179029      NaN          NaN
# 2017-02-23 16:00:00   3.9  0.169685      NaN          NaN
# 2017-02-23 17:00:00   4.7  0.169549      9.0          NaN
# 2017-02-28 23:00:00   1.4  0.238934      NaN          NaN
#
# [1193 rows x 12 columns]

# %%
# drop NA now 
data_new.dropna(inplace=True)
data_new.drop(columns=['PM2.5','PM1hour'], inplace=True)
data_new
# Out:
#                      PM10   SO2   NO2      CO    O3    PRES  RAIN  WSPM  \
# date
# 2013-03-01 00:00:00   6.0   3.0   8.0   300.0  44.0  1025.8   0.0   9.3
# 2013-03-01 01:00:00  12.0   3.0   7.0   300.0  47.0  1026.1   0.0   9.4
# 2013-03-01 05:00:00  11.0   3.0   7.0   200.0  45.0  1028.2   0.0   1.7
# 2013-03-01 06:00:00  12.0   3.0   9.0   300.0  74.0  1029.0   0.0   1.6
# 2013-03-01 07:00:00  13.0   3.0  23.0   300.0  59.0  1030.5   0.0   1.7
# ...                   ...   ...   ...     ...   ...     ...   ...   ...
# 2017-02-28 18:00:00  35.0   6.0  39.0   500.0  67.0  1013.5   0.0   1.3
# 2017-02-28 19:00:00  72.0   8.0  92.0   800.0  16.0  1014.2   0.0   1.8
# 2017-02-28 20:00:00  55.0  17.0  86.0  1100.0  19.0  1014.5   0.0   1.5
# 2017-02-28 21:00:00  28.0   4.0  30.0   500.0  64.0  1014.6   0.0   1.7
# 2017-02-28 22:00:00  20.0   9.0  33.0   500.0  59.0  1015.2   0.0   1.8
#
#                            RH  PM2.5Change
# date
# 2013-03-01 00:00:00  0.209222          9.0
# 2013-03-01 01:00:00  0.197983          2.0
# 2013-03-01 05:00:00  0.209214          1.0
# 2013-03-01 06:00:00  0.247706          1.0
# 2013-03-01 07:00:00  0.217901         -5.0
# ...                       ...          ...
# 2017-02-28 18:00:00  0.168719         12.0
# 2017-02-28 19:00:00  0.188669         20.0
# 2017-02-28 20:00:00  0.238267        -29.0
# 2017-02-28 21:00:00  0.199573          0.0
# 2017-02-28 22:00:00  0.219519         -3.0
#
# [30347 rows x 10 columns]

# %% [markdown]
# ## Bayesian inference
#
# ### Our model
# $$\frac{\mathrm{d}PM_{2.5}}{\mathrm{d}t} =Background + \sum_{i=0}^5 \alpha_ix_i(x_1=RH,x_2=windspeed,x_3=CO,x_4=NO,x_5=SO_2)$$

# %%
# remove PM10
data_new.drop(columns=['PM10'], inplace=True)
data_new
# Out:
#                       SO2   NO2      CO    O3    PRES  RAIN  WSPM        RH  \
# date
# 2013-03-01 00:00:00   3.0   8.0   300.0  44.0  1025.8   0.0   9.3  0.209222
# 2013-03-01 01:00:00   3.0   7.0   300.0  47.0  1026.1   0.0   9.4  0.197983
# 2013-03-01 05:00:00   3.0   7.0   200.0  45.0  1028.2   0.0   1.7  0.209214
# 2013-03-01 06:00:00   3.0   9.0   300.0  74.0  1029.0   0.0   1.6  0.247706
# 2013-03-01 07:00:00   3.0  23.0   300.0  59.0  1030.5   0.0   1.7  0.217901
# ...                   ...   ...     ...   ...     ...   ...   ...       ...
# 2017-02-28 18:00:00   6.0  39.0   500.0  67.0  1013.5   0.0   1.3  0.168719
# 2017-02-28 19:00:00   8.0  92.0   800.0  16.0  1014.2   0.0   1.8  0.188669
# 2017-02-28 20:00:00  17.0  86.0  1100.0  19.0  1014.5   0.0   1.5  0.238267
# 2017-02-28 21:00:00   4.0  30.0   500.0  64.0  1014.6   0.0   1.7  0.199573
# 2017-02-28 22:00:00   9.0  33.0   500.0  59.0  1015.2   0.0   1.8  0.219519
#
#                      PM2.5Change
# date
# 2013-03-01 00:00:00          9.0
# 2013-03-01 01:00:00          2.0
# 2013-03-01 05:00:00          1.0
# 2013-03-01 06:00:00          1.0
# 2013-03-01 07:00:00         -5.0
# ...                          ...
# 2017-02-28 18:00:00         12.0
# 2017-02-28 19:00:00         20.0
# 2017-02-28 20:00:00        -29.0
# 2017-02-28 21:00:00          0.0
# 2017-02-28 22:00:00         -3.0
#
# [30347 rows x 9 columns]

# %%
data_new['PM2.5Change'].plot()

# %%
data_new['PM2.5Change'].plot.hist(density=True)

# %%
# we assume that the change rate is a normal distribution and its expectation mu follows our model

# x1:RH
X1 = data_new['RH'].to_numpy()
# x2:windspeed
X2 = data_new['WSPM'].to_numpy()
# x3:CO
X3 = data_new['CO'].to_numpy()
# x4:NO2
X4 = data_new['NO2'].to_numpy()
# x5:SO2
X5 = data_new['SO2'].to_numpy()

# observation
Y = data_new['PM2.5Change'].to_numpy()

# %%
import pymc3 as pm

with pm.Model() as pm25_model:
    alpha1 = pm.HalfNormal('alpha1',sd=10)
    alpha2 = pm.HalfNormal('alpha2',sd=10)
    alpha3 = pm.HalfNormal('alpha3',sd=10)
    alpha4 = pm.HalfNormal('alpha4',sd=10)
    alpha5 = pm.HalfNormal('alpha5',sd=10)
    c = pm.Normal('c',mu=0,sd=10)
    
    sigma = pm.HalfNormal('sigma',sd=5)
    
    mu = alpha1 * X1 + alpha2 * X2 + alpha3 * X3 + alpha4 * X4 + alpha5 * X5 + c
    
    Y_obs = pm.Normal('Y_obs', mu=mu, sd=sigma, observed=Y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-324ab9eb6130> in <module>
#       1 import pymc3 as pm
#       2
# ----> 3 with pm.Model() as pm25_model:
#       4     alpha1 = pm.HalfNormal('alpha1',sd=10)
#       5     alpha2 = pm.HalfNormal('alpha2',sd=10)
#
# AttributeError: module 'pymc3' has no attribute 'Model'
